# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Estruturas de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Listas;</li>
#   <li>Conjuntos;</li>
#   <li>Dicionários.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# Criei uma lista chamada `filmes` com o nome dos 10 primeiros filmes mais bem avaliados no site no [IMDB](https://www.imdb.com/chart/top/). Imprima o resultado.

# %%
filmes = ["The Shawshank Redemption", "The Godfather", "The Dark Knight", "The Godfather Part II", "12 Angry Men", "Schindler's List", "The Lord of the Rings: The Return of the King", "Pulp Fiction", "The Lord of the Rings: The Fellowship of the Ring", "The Good, the Bad and the Ugly"]
print(filmes)

# %% [markdown]
# Simule a movimentação do *ranking*. Utilize os métodos `insert` e `pop` para trocar a posição do primeiro e do segundo filme da lista. Imprima o resultado.

# %%
filmes.insert(0,filmes.pop(1))
print(filmes)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# Aconteceu um erro no seu *ranking*. Simule a duplicação dos três últimos filmes da lista. Imprima o resultado.

# %%
filmes = filmes + filmes[-3:]
print(filmes)

# %% [markdown]
# Utiliza a conversão `set` e `list` para remover os valores duplicados. Imprima o resultado.

# %%
filmes = list(set(filmes))
print(filmes)

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# Repita os exercícios da parte 1 (listas). Os elementos da lista `filmes` devem ser dicionários no seguinte formato: `{'nome': <nome-do-filme>, 'ano': <ano do filme>, 'sinopse': <sinopse do filme>}`.

# %%
filmes = [
    {'nome': 'The Shawshank Redemption', 'ano': 1994, 'sinopse': 'Dois presidiários formam uma amizade ao longo dos anos e encontram consolo e eventual redenção através de atos de decência comum.'},
    {'nome': 'The Godfather', 'ano': 1972, 'sinopse': 'O envelhecimento patriarca de uma dinastia do crime organizado transfere o controle de seu império clandestino para seu filho relutante.'},
    {'nome': 'The Dark Knight', 'ano': 2008, 'sinopse': 'Quando o Joker lança uma ameaça de caos sobre Gotham, Batman deve aceitar um dos maiores testes psicológicos e físicos de sua capacidade de combater a injustiça.'},
    {'nome': 'The Godfather: Part II', 'ano': 1974, 'sinopse': 'As primeiras e atuais carreiras de Michael Corleone como dono de um sindicato do crime são mostradas, assim como a história de seu pai.'},
    {'nome': '12 Angry Men', 'ano': 1957, 'sinopse': 'Um júri deve decidir o destino de um adolescente acusado de assassinato.'},
    {'nome': 'Schindler’s List', 'ano': 1993, 'sinopse': 'Na Polônia ocupada pelos alemães durante a Segunda Guerra Mundial, Oskar Schindler gradualmente se torna preocupado com seus trabalhadores judeus depois de testemunhar a perseguição deles pelos nazistas.'},
    {'nome': 'The Lord of the Rings: The Return of the King', 'ano': 2003, 'sinopse': 'Gandalf e Aragorn lideram o Mundo dos Homens contra o exército de Sauron para chamar a atenção dele, permitindo que Frodo e Sam cheguem ao Monte da Perdição.'},
    {'nome': 'Pulp Fiction', 'ano': 1994, 'sinopse': 'As vidas de dois assassinos de aluguel, um boxeador, a esposa de um gângster e um casal de bandidos se entrelaçam em quatro histórias de violência e redenção.'},
    {'nome': 'The Lord of the Rings: The Fellowship of the Ring', 'ano': 2001, 'sinopse': 'Um manso hobbit do Condado e oito companheiros partem em uma jornada para destruir o poderoso Um Anel e salvar a Terra-média das Trevas.'},
    {'nome': 'The Good, the Bad and the Ugly', 'ano': 1966, 'sinopse': 'Um impostor se junta com dois homens para encontrar fortuna num remoto cemitério.'}
]
print(filmes)
